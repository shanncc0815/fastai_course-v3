# %% [markdown]
# # Lesson 6: pets revisited

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

from fastai.vision import *

# %%
bs = 16

# %% [markdown]
# ## Data augmentation

# %%
tfms = get_transforms(do_flip=False, flip_vert=False, max_rotate=15, max_zoom=1.1, p_affine=0.5, max_lighting=0.5, p_lighting=0.1, max_warp=0)

# %%
path_os = '/github/course-v3/nbs/dl1/data/HumanOA_0401_padding3000_v2_combine_valid40'
#data = ImageDataBunch.from_folder(path_os, ds_tfms=tfms, size=224, bs = bs)

data = (ImageList.from_folder(path_os) #Where to find the data? -> in path and its subfolders
        .split_by_folder()              #How to split in train/valid? -> use the folders
        .label_from_folder()            #How to label? -> depending on the folder of the filenames
        .add_test_folder()              #Optionally add a test set (here default name is test)
        .transform(tfms, size=224)       #Data augmentation? -> use tfms with a size of 64
        .databunch())                   #Finally? -> use the defaults for conversion to ImageDataBunch

# %% [markdown]
# ## Train a model

# %%
gc.collect()
learn = cnn_learner(data, models.resnet34, metrics=error_rate, bn_final=True)

# %%
learn.fit_one_cycle(3, slice(1e-2), pct_start=0.8)
# Out:
# Total time: 04:59 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.044696</td>
#       <td>1.142388</td>
#       <td>0.462500</td>
#       <td>01:41</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.815554</td>
#       <td>0.644355</td>
#       <td>0.243750</td>
#       <td>01:39</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.552444</td>
#       <td>0.222444</td>
#       <td>0.037500</td>
#       <td>01:38</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.unfreeze()
learn.fit_one_cycle(2, max_lr=slice(1e-6,1e-3), pct_start=0.8)
# Out:
# Total time: 03:19 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.312348</td>
#       <td>0.174450</td>
#       <td>0.018750</td>
#       <td>01:39</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.272973</td>
#       <td>0.146065</td>
#       <td>0.006250</td>
#       <td>01:40</td>
#     </tr>
#   </tbody>
# </table>

# %%
idx=0
print(len(data.test_ds))
x,y = data.test_ds[0]
x.show()
#data.test_ds.y[idx]
data.test_ds.y[idx]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-b87c1f450426> in <module>
#       1 idx=0
# ----> 2 print(len(data.test_ds))
#       3 x,y = data.test_ds[0]
#       4 x.show()
#       5 #data.test_ds.y[idx]
#
# TypeError: object of type 'NoneType' has no len()

# %%
learn.fit_one_cycle(2, max_lr=slice(1e-6,1e-4))
# Out:
# Total time: 02:58 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.080193</td>
#       <td>0.043591</td>
#       <td>0.000000</td>
#       <td>01:30</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.076382</td>
#       <td>0.041643</td>
#       <td>0.000000</td>
#       <td>01:28</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('HumanOA_0402_padding3000_v2_combine_test0119_224')

# %%
learn.load('HumanOA_0402_padding3000_v2_combine_test0119_224')
# Out:
# Learner(data=ImageDataBunch;
#
# Train: LabelList (2659 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: CategoryList
# OA_both,OA_both,OA_both,OA_both,OA_both
# Path: /github/course-v3/nbs/dl1/data/HumanOA_0401_padding3000_v2_combine_valid40;
#
# Valid: LabelList (160 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: CategoryList
# OA_both,OA_both,OA_both,OA_both,OA_both
# Path: /github/course-v3/nbs/dl1/data/HumanOA_0401_padding3000_v2_combine_valid40;
#
# Test: LabelList (3519 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: EmptyLabelList
# ,,,,
# Path: /github/course-v3/nbs/dl1/data/HumanOA_0401_padding3000_v2_combine_valid40, model=Sequential(
#   (0): Sequential(
# ...

# %% [markdown]
# ## Heatmap

# %%
m = learn.model.eval();

# %%
from fastai.callbacks.hooks import *

# %%
def hooked_backward(cat=y):
    with hook_output(m[0]) as hook_a: 
        with hook_output(m[0], grad=True) as hook_g:
            preds = m(xb)
            preds[0,int(cat)].backward()
    return hook_a,hook_g

# %%
def show_heatmap(hm):
    _,ax = plt.subplots()
    xb_im.show(ax)
    ax.imshow(hm, alpha=0.6, extent=(0,224,224,0),
              interpolation='bilinear', cmap='magma');

# %%
testNum = len(data.test_ds)
idx=0
x,y = data.test_ds[idx]
xb,_ = data.one_item(x)
#xb_im = Image(data.denorm(xb)[0])  - for gray level images
xb_im = Image(xb[0])
xb = xb.cuda()
hook_a,hook_g = hooked_backward(0)
acts  = hook_a.stored[0].cpu()
avg_acts = acts.mean(0)

# %%
show_heatmap(avg_acts)

# %% [markdown]
# ## Grad-CAM

# %% [markdown]
# Paper: [Grad-CAM: Visual Explanations from Deep Networks via Gradient-based Localization](https://arxiv.org/abs/1610.02391)

# %%
grad = hook_g.stored[0][0].cpu()
grad_chan = grad.mean(1).mean(1)
grad.shape,grad_chan.shape
# Out:
# (torch.Size([512, 7, 7]), torch.Size([512]))

# %%
mult = (acts*grad_chan[...,None,None]).mean(0)

# %%
show_heatmap(mult)

# %% [markdown]
# # Test with HipOP20190119 images

# %%
testNum = len(data.test_ds)
idx=0
x,y = data.test_ds[idx]
xb,_ = data.one_item(x)
xb_im = Image(xb[0])
xb = xb.cuda()

# %%
img = learn.data.test_ds[idx][0]
print(print(data.classes))
learn.predict(img)
# Out:
# ['OA_BeforeSurgery', 'OA_both', 'OA_left', 'OA_right']
# None
# (Category OA_left, tensor(2), tensor([0.0176, 0.0222, 0.9313, 0.0289]))

# %%
print(data.classes[0])
hook_a,hook_g = hooked_backward(0)
acts = hook_a.stored[0].cpu()
grad = hook_g.stored[0][0].cpu()

grad_chan = grad.mean(1).mean(1)
mult = (acts*grad_chan[...,None,None]).mean(0)
# Out:
# OA_BeforeSurgery

# %%
show_heatmap(mult)

# %%
print(data.classes[1])
hook_a,hook_g = hooked_backward(1)
acts = hook_a.stored[0].cpu()
grad = hook_g.stored[0][0].cpu()

grad_chan = grad.mean(1).mean(1)
mult = (acts*grad_chan[...,None,None]).mean(0)
show_heatmap(mult)
# Out:
# OA_both

# %%
print(data.classes[2])
hook_a,hook_g = hooked_backward(2)
acts = hook_a.stored[0].cpu()
grad = hook_g.stored[0][0].cpu()

grad_chan = grad.mean(1).mean(1)
mult = (acts*grad_chan[...,None,None]).mean(0)
show_heatmap(mult)
# Out:
# OA_left

# %%
print(data.classes[3])
hook_a,hook_g = hooked_backward(3)
acts = hook_a.stored[0].cpu()
grad = hook_g.stored[0][0].cpu()

grad_chan = grad.mean(1).mean(1)
mult = (acts*grad_chan[...,None,None]).mean(0)
show_heatmap(mult)
# Out:
# OA_right
